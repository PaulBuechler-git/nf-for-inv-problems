# %%
import sqlite3

import matplotlib.pyplot as plt

# %%
#TABLE flow_model_train_loss(step, loss)
version = 3
loss_db_path = f'results/patch_nr/custom_patch_nr/version_{version}/loss.db'

# %%
connection = sqlite3.connect(loss_db_path)
cursor = connection.cursor()

# %%
cursor.execute('SELECT * from flow_model_train_loss')
step, loss =zip(*cursor.fetchall())
cursor.execute('SELECT * from flow_model_validation_loss')
val_step, val_loss =zip(*cursor.fetchall())

# %%
plt.plot(step, loss, label='Training Loss', color='lightsteelblue')
plt.plot(val_step, val_loss, label='Validation Loss', color='royalblue')
plt.ylabel('Loss')
plt.xlabel('Iterations')
plt.legend()
plt.show()
